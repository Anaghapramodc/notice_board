# %%
# print("hello wolrd")

# a=12
# b="anagha"
# c="a"
# d=2.3
# e="i am anagha"
# f=1+2j
# print(a,b,c,d,e,f)
x,y,z=12,23,"ksj"
print(x,y,z)#this is a doisjddkhc

a=b=c=11
print(a,b,c)
# Out:
# 12 23 ksj
# 11 11 11

# %%
a=12
b="anagha"
c="a"
d=2.3
e="i am anagha"
f=1+2j
x=True
print(type(a))
print(type(d))
type(f)
type(b)
type(c)
type(e)
type(x)

x=12
y=23
print(x,y)
x,y=y,x
print(x,y)
# Out:
# <class 'int'>
# <class 'float'>
# 12 23
# 23 12

# %%
#list

a=[1,2,3,4,"hello",'a',[1,2,3,4],2,3,3]
# print(a)

# print(a[4])
# print(a[0:4:1])
# print(a[-1:-4:-1])
print(a[::-1])

l=[1,2,3,4,50]
# l.append(2)
# print(l)
# l.insert(1,15)
# # print(l)
# print(len(l))
# l.sort(reverse=True)
# print(l)
print(max(l))
print(min(l))
# for i in l:
#     print(i)

# print(type(l))
# Out:
# [3, 3, 2, [1, 2, 3, 4], 'a', 'hello', 4, 3, 2, 1]
# 50
# 1

# %%
l=[1,2,3,4,5]
# sum(l)
# sum=0
# for i in l:
#     sum=sum+i
# print(sum)


l1=[]
for i in l:
    if i%2==0:
        l1.append(i)
print(len(l1))
# Out:
# 2

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
arr=np.array([20,20,30,10])
arr1=np.array([[1,2,3],[4,4,6],[1,54,7]])

arr.shape
arr1.shape
arr.ndim
arr1.ndim
arr.size
arr1.size
arr.dtype
arr1.dtype

# a=np.array([1,2,3])
# b=np.array([4,5,6])
# # print(a+b)
# # print(a*5)
# # np.zeros(2)
# # np.ones(5)
# np.arange(2,11,2)


arr=np.array([20,20,30,10])
arr.max()
arr.min()
arr.mean()
arr.std()
# Out:
# np.float64(7.0710678118654755)

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[4,7,5,8]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("simple line plot")
plt.show()

# %%
name=["A","B","C"]
mark=[80,30,60]
plt.bar(name,mark)
plt.show()

# %%
x=[1,2,3,4]
y=[4,7,5,8]
plt.scatter(x,y)

# %%
arr=np.array([20,20,30,10])

len(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[463], line 4
#       1 arr=np.array([20,20,30,10])
#       3 len(arr)
# ----> 4 sum(arr)
#
# TypeError: 'int' object is not callable
